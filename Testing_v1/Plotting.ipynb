# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import os
# List of all the test models
path = 'Test Models/'

# List of all the test models
dir = os.listdir(path)
file = 'metrics.csv'

data = {'Population Size': [], 'Mean Fitness': [], 'Max Fitness': []}

for folder in dir:
    df = pd.read_csv(path + folder + '/' + file)
# Out:
#    generation  best_fitness  mean_fitness  best_agent  duration  \
# 0           1             5             4           4  2.568902
# 1           2             5             4           0  2.541503
# 2           3             5             4           3  2.697282
# 3           4             5             4           1  2.373581
# 4           5             5             4           0  2.579831
#
#    total duration                all_fitness
# 0        2.568902  [4.0, 4.0, 4.0, 4.0, 5.0]
# 1        5.110405  [5.0, 5.0, 4.0, 5.0, 5.0]
# 2        7.807687  [4.0, 4.0, 4.0, 5.0, 5.0]
# 3       10.181268  [4.0, 5.0, 5.0, 5.0, 5.0]
# 4       12.761099  [5.0, 5.0, 5.0, 4.0, 5.0]
#    generation  best_fitness  mean_fitness  best_agent   duration  \
# 0           1            35            10           8  11.604682
# 1           2            31            18           6  20.176299
# 2           3            30            20           8  21.713672
# ...
